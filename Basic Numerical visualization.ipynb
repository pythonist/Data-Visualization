# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
df = pd.read_excel('Banking Data.xlsx',skiprows = 3)

# %%
df.describe()
# Out:
#               Age   Education         Income     Home Value         Wealth  \
# count  102.000000  102.000000     102.000000     102.000000     102.000000
# mean    35.451961   12.983333   48810.990196  106844.725490  109025.764706
# std      3.886476    1.005144   19361.876723   38795.325726   59836.600742
# min     19.500000   11.000000    7741.000000   40313.000000   24999.000000
# 25%     33.925000   12.400000   35078.250000   83016.500000   70262.750000
# 50%     36.100000   12.700000   47655.500000   97743.500000  102348.000000
# 75%     37.575000   13.200000   60157.000000  121790.500000  142517.750000
# max     43.100000   16.100000  111548.000000  276139.000000  331009.000000
#
#             Balance
# count    102.000000
# mean   24887.882353
# std     8697.811347
# min     5956.000000
# 25%    20035.500000
# 50%    24660.500000
# 75%    29180.250000
# max    56569.000000

# %%
df.head()
# Out:
#     Age  Education  Income  Home Value  Wealth  Balance
# 0  35.9       14.8   91033      183104  220741    38517
# 1  37.7       13.8   86748      163843  223152    40618
# 2  36.8       13.8   72245      142732  176926    35206
# 3  35.3       13.2   70639      145024  166260    33434
# 4  35.3       13.2   64879      135951  148868    28162

# %%
df.isna().sum()
# Out:
# Age           0
# Education     0
# Income        0
# Home Value    0
# Wealth        0
# Balance       0
# dtype: int64

# %%
sns.scatterplot(x='Balance',y='Age',data=df)

# %%
import matplotlib.pyplot as plt

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.skew(axis=0)
# Out:
# Age          -1.605908
# Education     1.724875
# Income        0.606144
# Home Value    1.491980
# Wealth        0.751908
# Balance       0.603582
# dtype: float64

# %%
df.kurt(axis=0)
# Out:
# Age           4.411315
# Education     3.244492
# Income        0.949031
# Home Value    3.537029
# Wealth        1.003137
# Balance       1.484152
# dtype: float64

# %%
df.plot(kind='box')

# %%
df.plot()

# %%
sns.boxplot('Age',data=df)
